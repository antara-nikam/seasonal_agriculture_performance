# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("seasonal_agriculture_performance_dataset (2).csv")
df.head()
# Out:
#    Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 0  SF10001  Andhra Pradesh    Rajkot   Wheat  Kharif                0.53
# 1  SF10002     Maharashtra  Nalgonda   Maize  Kharif                6.53
# 2  SF10003       Telangana  Warangal  Pulses    Rabi                4.86
# 3  SF10004       Telangana    Indore    Rice  Kharif                4.50
# 4  SF10005       Karnataka  Ludhiana   Maize    Zaid                4.21
#
#    Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 0        486.4               24.3          69.1                 5.8  ...
# 1        855.4               25.7          78.4                 5.1  ...
# 2        455.6               23.9          56.4                10.3  ...
# 3        753.2               29.7          65.2                 6.3  ...
# 4        101.6               34.1          55.2                 6.5  ...
#
#    Seed_Quality_Score  Yield_Tonnes_Ha  Production_Tonnes  \
# ...

# %%
df.tail()
# Out:
#       Farm_ID           State  District    Crop  Season  Farm_Area_Hectares  \
# 3995  SF13996       Karnataka    Rajkot   Wheat  Kharif                4.72
# 3996  SF13997       Karnataka   Krishna  Chilli  Kharif                8.77
# 3997  SF13998  Andhra Pradesh     Erode  Pulses    Zaid               10.47
# 3998  SF13999          Punjab  Warangal  Cotton  Kharif                1.73
# 3999  SF14000          Punjab    Nashik   Wheat  Kharif                3.31
#
#       Rainfall_mm  Avg_Temperature_C  Humidity_pct  Sunlight_Hours_Day  ...  \
# 3995        865.4               27.3          51.4                 6.3  ...
# 3996        947.5               29.2          85.5                 6.1  ...
# 3997         80.0               35.4          68.5                 8.6  ...
# 3998        475.0               28.2          61.7                 6.4  ...
# 3999        984.3               25.8          77.2                 5.9  ...
#
# ...

# %%
df.shape
# Out:
# (4000, 28)

# %%
df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Farm_ID                        4000 non-null   str
#  1   State                          4000 non-null   str
#  2   District                       4000 non-null   str
#  3   Crop                           4000 non-null   str
#  4   Season                         4000 non-null   str
#  5   Farm_Area_Hectares             4000 non-null   float64
#  6   Rainfall_mm                    3952 non-null   float64
#  7   Avg_Temperature_C              4000 non-null   float64
#  8   Humidity_pct                   4000 non-null   float64
#  9   Sunlight_Hours_Day             4000 non-null   float64
#  10  Soil_pH                        4000 non-null   float64
#  11  Soil_Moisture_pct              3960 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Farm_Area_Hectares  Rainfall_mm  Avg_Temperature_C  Humidity_pct  \
# count         4000.000000  3952.000000         4000.00000   4000.000000
# mean             7.888265   601.152657           26.81890     63.210500
# std              4.223764   288.925025            3.81818     11.960834
# min              0.500000    80.000000           16.20000     25.000000
# 25%              4.260000   370.200000           23.90000     54.775000
# 50%              7.895000   582.000000           26.90000     63.000000
# 75%             11.650000   834.950000           29.60000     71.900000
# max             15.000000  1395.200000           39.70000     95.000000
#
#        Sunlight_Hours_Day      Soil_pH  Soil_Moisture_pct  Nitrogen_kg_ha  \
# count         4000.000000  4000.000000        3960.000000     4000.000000
# mean             7.323050     6.701010          26.508232      120.250825
# std              1.121186     0.641461           6.712484       31.216452
# ...

# %%
df["Season"].value_counts()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# Name: count, dtype: int64

# %%
df["Crop"].value_counts()
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                      48
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                40
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Farm_ID"].duplicated().sum()
# Out:
# np.int64(0)

# %%
df["State"].value_counts()
# Out:
# State
# Andhra Pradesh    529
# Telangana         516
# Maharashtra       512
# Madhya Pradesh    497
# Karnataka         489
# Gujarat           488
# Tamil Nadu        485
# Punjab            484
# Name: count, dtype: int64

# %%
df["District"].value_counts()
# Out:
# District
# Ludhiana    427
# Warangal    422
# Nalgonda    415
# Erode       403
# Rajkot      401
# Krishna     393
# Indore      392
# Guntur      390
# Raichur     386
# Nashik      371
# Name: count, dtype: int64

# %%
df["Crop"].value_counts()
# Out:
# Crop
# Rice         690
# Wheat        614
# Maize        551
# Cotton       508
# Pulses       496
# Groundnut    424
# Chilli       412
# Sugarcane    305
# Name: count, dtype: int64

# %%
df["Irrigation_Method"].value_counts()
# Out:
# Irrigation_Method
# Flood        1310
# Rainfed      1041
# Drip          915
# Sprinkler     734
# Name: count, dtype: int64

# %%
missing = df.isnull().sum()

missing_percentage = (missing / len(df)) * 100

missing_table = pd.DataFrame({
    "Missing Values": missing,
    "Missing Percentage": missing_percentage
})

missing_table[missing_table["Missing Values"] > 0]
# Out:
#                    Missing Values  Missing Percentage
# Rainfall_mm                    48                 1.2
# Soil_Moisture_pct              40                 1.0
# Yield_Tonnes_Ha                32                 0.8

# %%
df.describe().T
# Out:
#                                 count           mean            std  \
# Farm_Area_Hectares             4000.0       7.888265       4.223764
# Rainfall_mm                    3952.0     601.152657     288.925025
# Avg_Temperature_C              4000.0      26.818900       3.818180
# Humidity_pct                   4000.0      63.210500      11.960834
# Sunlight_Hours_Day             4000.0       7.323050       1.121186
# Soil_pH                        4000.0       6.701010       0.641461
# Soil_Moisture_pct              3960.0      26.508232       6.712484
# Nitrogen_kg_ha                 4000.0     120.250825      31.216452
# Phosphorus_kg_ha               4000.0      57.781850      17.015074
# Potassium_kg_ha                4000.0     104.760050      27.742681
# Fertilizer_kg_ha               4000.0     186.036000      60.260583
# Pesticide_Litre_ha             4000.0       5.070935       1.978879
# Seed_Quality_Score             4000.0       0.826138       0.101747
# ...

# %%
df.groupby("Season")[["Rainfall_mm", "Soil_Moisture_pct", "Yield_Tonnes_Ha"]].mean()
# Out:
#         Rainfall_mm  Soil_Moisture_pct  Yield_Tonnes_Ha
# Season
# Kharif   852.084205          31.198410         5.643973
# Rabi     436.000124          24.050620         5.080498
# Zaid     299.421784          19.170085         4.665942

# %%
df.groupby("Season")[["Rainfall_mm", "Soil_Moisture_pct", "Yield_Tonnes_Ha"]].apply(lambda x: x.isnull().sum())
# Out:
#         Rainfall_mm  Soil_Moisture_pct  Yield_Tonnes_Ha
# Season
# Kharif           19                 18                7
# Rabi             18                 13               20
# Zaid             11                  9                5

# %%
df["Calculated_Production"] = (
    df["Farm_Area_Hectares"] * df["Yield_Tonnes_Ha"]
)

# %%
df[["Production_Tonnes", "Calculated_Production"]].head(10)
# Out:
#    Production_Tonnes  Calculated_Production
# 0               1.30                 1.3038
# 1               1.96                 1.9590
# 2               2.53                 2.5272
# 3               8.28                 8.2800
# 4               9.30                 9.3041
# 5               3.93                 3.9312
# 6              20.57                20.5689
# 7               6.30                 6.3012
# 8              10.68                10.6794
# 9              31.35                31.3501

# %%
df["Calculated_Revenue"] = (
    df["Production_Tonnes"] * df["Market_Price_INR_Tonne"]
)

# %%
df[["Revenue_INR", "Calculated_Revenue"]].head(10)
# Out:
#    Revenue_INR  Calculated_Revenue
# 0        30810            30810.00
# 1        40401            40401.48
# 2       190466           190465.99
# 3       200740           200740.32
# 4       193607           193607.40
# 5       269570           269570.49
# 6       472102           472102.07
# 7       441265           441264.60
# 8       755834           755834.28
# 9      2958907          2958907.05

# %%
df["Calculated_Profit"] = (
    df["Revenue_INR"] - df["Total_Cost_INR"]
)

# %%
df[["Profit_INR", "Calculated_Profit"]].head(10)
# Out:
#    Profit_INR  Calculated_Profit
# 0      -11852             -11852
# 1     -451950            -451950
# 2     -124744            -124744
# 3      -95704             -95704
# 4     -144352            -144352
# 5      -32763             -32763
# 6      -41239             -41239
# 7        5065               5065
# 8      230705             230705
# 9     1954835            1954835

# %%
df["Rainfall_mm"] = df.groupby("Season")["Rainfall_mm"].transform(
    lambda x: x.fillna(x.median())
)

df["Soil_Moisture_pct"] = df.groupby("Season")["Soil_Moisture_pct"].transform(
    lambda x: x.fillna(x.median())
)

# %%
df_yield = df.dropna(subset=["Yield_Tonnes_Ha"]).copy()

# %%
df_yield.shape
# Out:
# (3968, 31)

# %%
df.drop(
    columns=["Calculated_Production", "Calculated_Revenue", "Calculated_Profit"],
    inplace=True
)

# %%
df.shape
# Out:
# (4000, 28)

# %%
df_yield = df.dropna(subset=["Yield_Tonnes_Ha"]).copy()

# %%
df_yield.shape
# Out:
# (3968, 28)

# %%
df.isnull().sum()
# Out:
# Farm_ID                           0
# State                             0
# District                          0
# Crop                              0
# Season                            0
# Farm_Area_Hectares                0
# Rainfall_mm                       0
# Avg_Temperature_C                 0
# Humidity_pct                      0
# Sunlight_Hours_Day                0
# Soil_pH                           0
# Soil_Moisture_pct                 0
# Nitrogen_kg_ha                    0
# Phosphorus_kg_ha                  0
# Potassium_kg_ha                   0
# Irrigation_Method                 0
# Fertilizer_kg_ha                  0
# Pesticide_Litre_ha                0
# Seed_Quality_Score                0
# Yield_Tonnes_Ha                  32
# Production_Tonnes                 0
# Market_Price_INR_Tonne            0
# Total_Cost_INR                    0
# Revenue_INR                       0
# Profit_INR                        0
# Water_Used_m3                     0
# ...

# %%
df_yield = df.dropna(subset=["Yield_Tonnes_Ha"]).copy()

# %%
df_yield.isnull().sum()
# Out:
# Farm_ID                          0
# State                            0
# District                         0
# Crop                             0
# Season                           0
# Farm_Area_Hectares               0
# Rainfall_mm                      0
# Avg_Temperature_C                0
# Humidity_pct                     0
# Sunlight_Hours_Day               0
# Soil_pH                          0
# Soil_Moisture_pct                0
# Nitrogen_kg_ha                   0
# Phosphorus_kg_ha                 0
# Potassium_kg_ha                  0
# Irrigation_Method                0
# Fertilizer_kg_ha                 0
# Pesticide_Litre_ha               0
# Seed_Quality_Score               0
# Yield_Tonnes_Ha                  0
# Production_Tonnes                0
# Market_Price_INR_Tonne           0
# Total_Cost_INR                   0
# Revenue_INR                      0
# Profit_INR                       0
# Water_Used_m3                    0
# Water_Efficiency_t_per_1000m3    0
# ...

# %%
df.columns
# Out:
# Index(['Farm_ID', 'State', 'District', 'Crop', 'Season', 'Farm_Area_Hectares',
#        'Rainfall_mm', 'Avg_Temperature_C', 'Humidity_pct',
#        'Sunlight_Hours_Day', 'Soil_pH', 'Soil_Moisture_pct', 'Nitrogen_kg_ha',
#        'Phosphorus_kg_ha', 'Potassium_kg_ha', 'Irrigation_Method',
#        'Fertilizer_kg_ha', 'Pesticide_Litre_ha', 'Seed_Quality_Score',
#        'Yield_Tonnes_Ha', 'Production_Tonnes', 'Market_Price_INR_Tonne',
#        'Total_Cost_INR', 'Revenue_INR', 'Profit_INR', 'Water_Used_m3',
#        'Water_Efficiency_t_per_1000m3', 'Disease_Pest_Risk_pct'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Farm_ID                              str
# State                                str
# District                             str
# Crop                                 str
# Season                               str
# Farm_Area_Hectares               float64
# Rainfall_mm                      float64
# Avg_Temperature_C                float64
# Humidity_pct                     float64
# Sunlight_Hours_Day               float64
# Soil_pH                          float64
# Soil_Moisture_pct                float64
# Nitrogen_kg_ha                   float64
# Phosphorus_kg_ha                 float64
# Potassium_kg_ha                  float64
# Irrigation_Method                    str
# Fertilizer_kg_ha                 float64
# Pesticide_Litre_ha               float64
# Seed_Quality_Score               float64
# Yield_Tonnes_Ha                  float64
# Production_Tonnes                float64
# Market_Price_INR_Tonne             int64
# Total_Cost_INR                     int64
# ...

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x="Season")

plt.title("Number of Farms by Season")
plt.xlabel("Season")
plt.ylabel("Number of Farms")
plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(data=df, x="Crop")

plt.title("Number of Farms by Crop")
plt.xlabel("Crop")
plt.ylabel("Number of Farms")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(data=df, x="State")

plt.title("Number of Farms by State")
plt.xlabel("State")
plt.ylabel("Number of Farms")
plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x="Irrigation_Method")

plt.title("Distribution of Irrigation Methods")
plt.xlabel("Irrigation Method")
plt.ylabel("Number of Farms")
plt.xticks(rotation=30)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(data=df, x="Rainfall_mm", bins=30, kde=True)

plt.title("Distribution of Rainfall")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Number of Farms")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(data=df, x="Avg_Temperature_C", bins=30, kde=True)

plt.title("Distribution of Average Temperature")
plt.xlabel("Average Temperature (°C)")
plt.ylabel("Number of Farms")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(data=df, x="Soil_Moisture_pct", bins=30, kde=True)

plt.title("Distribution of Soil Moisture")
plt.xlabel("Soil Moisture (%)")
plt.ylabel("Number of Farms")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(data=df_yield, x="Yield_Tonnes_Ha", bins=30, kde=True)

plt.title("Distribution of Crop Yield")
plt.xlabel("Yield (Tonnes/Ha)")
plt.ylabel("Number of Farms")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(data=df, x="Profit_INR", bins=40, kde=True)

plt.title("Distribution of Farm Profit")
plt.xlabel("Profit (INR)")
plt.ylabel("Number of Farms")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df_yield, y="Yield_Tonnes_Ha")

plt.title("Boxplot of Crop Yield")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, y="Profit_INR")

plt.title("Boxplot of Farm Profit")
plt.ylabel("Profit (INR)")

plt.show()

# %%
season_summary = df.groupby("Season").agg({
    "Rainfall_mm": "mean",
    "Avg_Temperature_C": "mean",
    "Humidity_pct": "mean",
    "Soil_Moisture_pct": "mean",
    "Yield_Tonnes_Ha": "mean",
    "Profit_INR": "mean"
}).round(2)

season_summary
# Out:
#         Rainfall_mm  Avg_Temperature_C  Humidity_pct  Soil_Moisture_pct  \
# Season
# Kharif       852.11              28.45         71.81              31.20
# Rabi         435.94              23.49         57.89              24.05
# Zaid         299.12              31.04         52.01              19.17
#
#         Yield_Tonnes_Ha  Profit_INR
# Season
# Kharif             5.64   178914.65
# Rabi               5.08    87689.47
# Zaid               4.67   -24804.82

# %%
df.groupby("Season").size()
# Out:
# Season
# Kharif    1779
# Rabi      1627
# Zaid       594
# dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Season", y="Rainfall_mm")

plt.title("Rainfall Variation Across Seasons")
plt.xlabel("Season")
plt.ylabel("Rainfall (mm)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Season", y="Soil_Moisture_pct")

plt.title("Soil Moisture Variation Across Seasons")
plt.xlabel("Season")
plt.ylabel("Soil Moisture (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df_yield, x="Season", y="Yield_Tonnes_Ha")

plt.title("Crop Yield Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Season", y="Profit_INR")

plt.title("Farm Profit Across Seasons")
plt.xlabel("Season")
plt.ylabel("Profit (INR)")

plt.show()

# %%
plt.figure(figsize=(10,6))

sns.countplot(
    data=df,
    x="Season",
    hue="Irrigation_Method"
)

plt.title("Irrigation Methods Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Farms")

plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    data=df,
    x="Season",
    hue="Crop"
)

plt.title("Crop Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Number of Farms")

plt.show()

# %%
season_performance = df.groupby("Season").agg(
    Farms=("Farm_ID", "count"),
    Avg_Rainfall_mm=("Rainfall_mm", "mean"),
    Avg_Temperature_C=("Avg_Temperature_C", "mean"),
    Avg_Soil_Moisture_pct=("Soil_Moisture_pct", "mean"),
    Avg_Yield_Tonnes_Ha=("Yield_Tonnes_Ha", "mean"),
    Avg_Profit_INR=("Profit_INR", "mean"),
    Avg_Water_Used_m3=("Water_Used_m3", "mean"),
    Avg_Disease_Risk_pct=("Disease_Pest_Risk_pct", "mean")
).round(2)

season_performance
# Out:
#         Farms  Avg_Rainfall_mm  Avg_Temperature_C  Avg_Soil_Moisture_pct  \
# Season
# Kharif   1779           852.11              28.45                  31.20
# Rabi     1627           435.94              23.49                  24.05
# Zaid      594           299.12              31.04                  19.17
#
#         Avg_Yield_Tonnes_Ha  Avg_Profit_INR  Avg_Water_Used_m3  \
# Season
# Kharif                 5.64       178914.65            6102.20
# Rabi                   5.08        87689.47            5846.99
# Zaid                   4.67       -24804.82            6419.89
#
#         Avg_Disease_Risk_pct
# Season
# Kharif                 54.47
# Rabi                   40.48
# Zaid                   38.22

# %%
numeric_cols = df.select_dtypes(include="number").columns

correlation = df[numeric_cols].corr()

correlation.round(2)
# Out:
#                                Farm_Area_Hectares  Rainfall_mm  \
# Farm_Area_Hectares                           1.00         0.01
# Rainfall_mm                                  0.01         1.00
# Avg_Temperature_C                            0.04         0.20
# Humidity_pct                                 0.00         0.53
# Sunlight_Hours_Day                           0.00        -0.37
# Soil_pH                                      0.01         0.02
# Soil_Moisture_pct                            0.00         0.52
# Nitrogen_kg_ha                               0.01         0.01
# Phosphorus_kg_ha                            -0.01         0.02
# Potassium_kg_ha                              0.00         0.03
# Fertilizer_kg_ha                             0.01         0.02
# Pesticide_Litre_ha                          -0.01         0.00
# Seed_Quality_Score                           0.02        -0.02
# Yield_Tonnes_Ha                              0.03         0.03
# ...

# %%
plt.figure(figsize=(16,12))

sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0
)

plt.title("Correlation Heatmap of Numerical Variables")

plt.show()

# %%
season_analysis = df.groupby("Season").agg(
    Farms=("Farm_ID", "count"),
    Avg_Rainfall_mm=("Rainfall_mm", "mean"),
    Avg_Temperature_C=("Avg_Temperature_C", "mean"),
    Avg_Humidity_pct=("Humidity_pct", "mean"),
    Avg_Soil_Moisture_pct=("Soil_Moisture_pct", "mean"),
    Avg_Sunlight_Hours=("Sunlight_Hours_Day", "mean"),
    Avg_Yield_Tonnes_Ha=("Yield_Tonnes_Ha", "mean"),
    Avg_Production_Tonnes=("Production_Tonnes", "mean"),
    Avg_Market_Price=("Market_Price_INR_Tonne", "mean"),
    Avg_Total_Cost=("Total_Cost_INR", "mean"),
    Avg_Revenue=("Revenue_INR", "mean"),
    Avg_Profit=("Profit_INR", "mean"),
    Avg_Water_Used=("Water_Used_m3", "mean"),
    Avg_Water_Efficiency=("Water_Efficiency_t_per_1000m3", "mean"),
    Avg_Disease_Risk=("Disease_Pest_Risk_pct", "mean")
).round(2)

season_analysis
# Out:
#         Farms  Avg_Rainfall_mm  Avg_Temperature_C  Avg_Humidity_pct  \
# Season
# Kharif   1779           852.11              28.45             71.81
# Rabi     1627           435.94              23.49             57.89
# Zaid      594           299.12              31.04             52.01
#
#         Avg_Soil_Moisture_pct  Avg_Sunlight_Hours  Avg_Yield_Tonnes_Ha  \
# Season
# Kharif                  31.20                6.79                 5.64
# Rabi                    24.05                7.59                 5.08
# Zaid                    19.17                8.18                 4.67
#
#         Avg_Production_Tonnes  Avg_Market_Price  Avg_Total_Cost  Avg_Revenue  \
# Season
# Kharif                  46.31          44850.91       531804.41    710719.06
# Rabi                    41.49          44747.97       513836.58    601526.05
# Zaid                    38.89          44212.03       543976.73    519171.90
#
# ...

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Rainfall_mm",
    estimator="mean"
)

plt.title("Average Rainfall Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Rainfall (mm)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Avg_Temperature_C",
    estimator="mean"
)

plt.title("Average Temperature Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Temperature (°C)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Soil_Moisture_pct",
    estimator="mean"
)

plt.title("Average Soil Moisture Across Seasons")
plt.xlabel("Season")
plt.ylabel("Soil Moisture (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df_yield,
    x="Season",
    y="Yield_Tonnes_Ha",
    estimator="mean"
)

plt.title("Average Crop Yield Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df_yield,
    x="Season",
    y="Yield_Tonnes_Ha"
)

plt.title("Yield Distribution Across Seasons")
plt.xlabel("Season")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Production_Tonnes",
    estimator="mean"
)

plt.title("Average Production Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Production (Tonnes)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Market_Price_INR_Tonne",
    estimator="mean"
)

plt.title("Average Market Price Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Market Price (INR/Tonne)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Total_Cost_INR",
    estimator="mean"
)

plt.title("Average Farming Cost Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Cost (INR)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Revenue_INR",
    estimator="mean"
)

plt.title("Average Revenue Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Revenue (INR)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Profit_INR",
    estimator="mean"
)

plt.title("Average Profit Across Seasons")
plt.xlabel("Season")
plt.ylabel("Average Profit (INR)")

plt.show()

# %%
df["Profit_Margin_pct"] = (
    df["Profit_INR"] / df["Revenue_INR"]
) * 100

# %%
profit_margin = df.groupby("Season")["Profit_Margin_pct"].mean().round(2)

profit_margin
# Out:
# Season
# Kharif   -38.64
# Rabi     -44.27
# Zaid     -69.35
# Name: Profit_Margin_pct, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Profit_Margin_pct",
    estimator="mean"
)

plt.title("Average Profit Margin Across Seasons")
plt.xlabel("Season")
plt.ylabel("Profit Margin (%)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Water_Used_m3",
    estimator="mean"
)

plt.title("Average Water Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Water Used (m³)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Water_Efficiency_t_per_1000m3",
    estimator="mean"
)

plt.title("Average Water Efficiency Across Seasons")
plt.xlabel("Season")
plt.ylabel("Water Efficiency (Tonnes per 1000 m³)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Disease_Pest_Risk_pct",
    estimator="mean"
)

plt.title("Average Disease and Pest Risk Across Seasons")
plt.xlabel("Season")
plt.ylabel("Disease/Pest Risk (%)")

plt.show()

# %%
crop_season_yield = df_yield.groupby(
    ["Season", "Crop"]
)["Yield_Tonnes_Ha"].mean().round(2)

crop_season_yield
# Out:
# Season  Crop
# Kharif  Chilli        1.73
#         Cotton        1.37
#         Groundnut     1.48
#         Maize         2.97
#         Pulses        1.04
#         Rice          2.71
#         Sugarcane    53.46
#         Wheat         2.26
# Rabi    Chilli        1.46
#         Cotton        1.19
#         Groundnut     1.22
#         Maize         2.61
#         Pulses        0.87
#         Rice          2.33
#         Sugarcane    43.94
#         Wheat         2.06
# Zaid    Chilli        1.18
#         Cotton        0.95
#         Groundnut     1.04
#         Maize         2.30
#         Pulses        0.65
#         Rice          1.90
#         Sugarcane    38.42
#         Wheat         1.75
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df_yield,
    x="Crop",
    y="Yield_Tonnes_Ha",
    hue="Season",
    estimator="mean"
)

plt.title("Crop Yield Across Different Seasons")
plt.xlabel("Crop")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.xticks(rotation=45)

plt.show()

# %%
best_crop_by_season = df_yield.groupby(
    ["Season", "Crop"]
)["Yield_Tonnes_Ha"].mean().reset_index()

best_crop_by_season = best_crop_by_season.loc[
    best_crop_by_season.groupby("Season")["Yield_Tonnes_Ha"].idxmax()
]

best_crop_by_season
# Out:
#     Season       Crop  Yield_Tonnes_Ha
# 6   Kharif  Sugarcane        53.459120
# 14    Rabi  Sugarcane        43.940394
# 22    Zaid  Sugarcane        38.423922

# %%
crop_season_profit = df.groupby(
    ["Season", "Crop"]
)["Profit_INR"].mean().round(2)

crop_season_profit
# Out:
# Season  Crop
# Kharif  Chilli        954380.42
#         Cotton        216999.55
#         Groundnut     108265.44
#         Maize         -39332.67
#         Pulses         43338.90
#         Rice          -64903.40
#         Sugarcane    1000790.81
#         Wheat        -105871.87
# Rabi    Chilli        638572.50
#         Cotton        107343.59
#         Groundnut      10416.54
#         Maize         -89133.40
#         Pulses        -14309.14
#         Rice          -98427.87
#         Sugarcane     731612.86
#         Wheat        -119954.57
# Zaid    Chilli        448659.09
#         Cotton        -53925.34
#         Groundnut     -68872.50
#         Maize        -194049.17
#         Pulses       -139227.81
#         Rice         -227239.34
#         Sugarcane     583635.80
#         Wheat        -193208.95
# Name: Profit_INR, dtype: float64

# %%
best_profit_crop = df.groupby(
    ["Season", "Crop"]
)["Profit_INR"].mean().reset_index()

best_profit_crop = best_profit_crop.loc[
    best_profit_crop.groupby("Season")["Profit_INR"].idxmax()
]

best_profit_crop
# Out:
#     Season       Crop    Profit_INR
# 6   Kharif  Sugarcane  1.000791e+06
# 14    Rabi  Sugarcane  7.316129e+05
# 22    Zaid  Sugarcane  5.836358e+05

# %%
irrigation_yield = df_yield.groupby(
    ["Season", "Irrigation_Method"]
)["Yield_Tonnes_Ha"].mean().round(2)

irrigation_yield
# Out:
# Season  Irrigation_Method
# Kharif  Drip                 7.26
#         Flood                5.00
#         Rainfed              5.72
#         Sprinkler            4.67
# Rabi    Drip                 6.21
#         Flood                5.10
#         Rainfed              3.94
#         Sprinkler            5.36
# Zaid    Drip                 5.85
#         Flood                4.03
#         Rainfed              3.06
#         Sprinkler            6.17
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=df_yield,
    x="Irrigation_Method",
    y="Yield_Tonnes_Ha",
    hue="Season",
    estimator="mean"
)

plt.title("Yield by Irrigation Method Across Seasons")
plt.xlabel("Irrigation Method")
plt.ylabel("Average Yield (Tonnes/Ha)")

plt.show()

# %%
irrigation_water = df.groupby(
    ["Season", "Irrigation_Method"]
)["Water_Used_m3"].mean().round(2)

irrigation_water
# Out:
# Season  Irrigation_Method
# Kharif  Drip                 5953.37
#         Flood                8229.27
#         Rainfed              3687.52
#         Sprinkler            5863.27
# Rabi    Drip                 5911.41
#         Flood                7766.83
#         Rainfed              3298.29
#         Sprinkler            6129.09
# Zaid    Drip                 5837.99
#         Flood                8113.69
#         Rainfed              3879.39
#         Sprinkler            7324.41
# Name: Water_Used_m3, dtype: float64

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=df,
    x="Irrigation_Method",
    y="Water_Used_m3",
    hue="Season",
    estimator="mean"
)

plt.title("Water Usage by Irrigation Method Across Seasons")
plt.xlabel("Irrigation Method")
plt.ylabel("Average Water Used (m³)")

plt.show()

# %%
state_season_yield = df_yield.groupby(
    ["Season", "State"]
)["Yield_Tonnes_Ha"].mean().round(2)

state_season_yield
# Out:
# Season  State
# Kharif  Andhra Pradesh    5.69
#         Gujarat           6.34
#         Karnataka         6.52
#         Madhya Pradesh    6.00
#         Maharashtra       5.45
#         Punjab            4.10
#         Tamil Nadu        5.52
#         Telangana         5.57
# Rabi    Andhra Pradesh    3.49
#         Gujarat           5.52
#         Karnataka         4.61
#         Madhya Pradesh    3.80
#         Maharashtra       5.50
#         Punjab            8.61
#         Tamil Nadu        4.56
#         Telangana         4.83
# Zaid    Andhra Pradesh    4.48
#         Gujarat           4.10
#         Karnataka         6.62
#         Madhya Pradesh    5.54
#         Maharashtra       2.29
#         Punjab            5.91
#         Tamil Nadu        4.10
#         Telangana         4.28
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
plt.figure(figsize=(12,6))

sns.barplot(
    data=df_yield,
    x="State",
    y="Yield_Tonnes_Ha",
    hue="Season",
    estimator="mean"
)

plt.title("Crop Yield Across States and Seasons")
plt.xlabel("State")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.xticks(rotation=45)

plt.show()

# %%
best_state_by_season = df_yield.groupby(
    ["Season", "State"]
)["Yield_Tonnes_Ha"].mean().reset_index()

best_state_by_season = best_state_by_season.loc[
    best_state_by_season.groupby("Season")["Yield_Tonnes_Ha"].idxmax()
]

best_state_by_season
# Out:
#     Season      State  Yield_Tonnes_Ha
# 2   Kharif  Karnataka         6.523689
# 13    Rabi     Punjab         8.609355
# 18    Zaid  Karnataka         6.623243

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Fertilizer_kg_ha",
    estimator="mean"
)

plt.title("Average Fertilizer Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Fertilizer (kg/ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Pesticide_Litre_ha",
    estimator="mean"
)

plt.title("Average Pesticide Usage Across Seasons")
plt.xlabel("Season")
plt.ylabel("Pesticide (Litre/ha)")

plt.show()

# %%
final_season_summary = df.groupby("Season").agg(
    Farms=("Farm_ID", "count"),
    Rainfall_mm=("Rainfall_mm", "mean"),
    Temperature_C=("Avg_Temperature_C", "mean"),
    Soil_Moisture_pct=("Soil_Moisture_pct", "mean"),
    Yield_Tonnes_Ha=("Yield_Tonnes_Ha", "mean"),
    Production_Tonnes=("Production_Tonnes", "mean"),
    Market_Price_INR=("Market_Price_INR_Tonne", "mean"),
    Cost_INR=("Total_Cost_INR", "mean"),
    Revenue_INR=("Revenue_INR", "mean"),
    Profit_INR=("Profit_INR", "mean"),
    Profit_Margin_pct=("Profit_Margin_pct", "mean"),
    Water_Used_m3=("Water_Used_m3", "mean"),
    Water_Efficiency=("Water_Efficiency_t_per_1000m3", "mean"),
    Disease_Risk_pct=("Disease_Pest_Risk_pct", "mean")
).round(2)

final_season_summary
# Out:
#         Farms  Rainfall_mm  Temperature_C  Soil_Moisture_pct  Yield_Tonnes_Ha  \
# Season
# Kharif   1779       852.11          28.45              31.20             5.64
# Rabi     1627       435.94          23.49              24.05             5.08
# Zaid      594       299.12          31.04              19.17             4.67
#
#         Production_Tonnes  Market_Price_INR   Cost_INR  Revenue_INR  \
# Season
# Kharif              46.31          44850.91  531804.41    710719.06
# Rabi                41.49          44747.97  513836.58    601526.05
# Zaid                38.89          44212.03  543976.73    519171.90
#
#         Profit_INR  Profit_Margin_pct  Water_Used_m3  Water_Efficiency  \
# Season
# Kharif   178914.65             -38.64        6102.20              5.89
# Rabi      87689.47             -44.27        5846.99              5.19
# Zaid     -24804.82             -69.35        6419.89              4.41
#
#         Disease_Risk_pct
# Season
# Kharif             54.47
# ...

# %%
yield_correlation = df_yield.select_dtypes(include="number").corr()["Yield_Tonnes_Ha"].sort_values(ascending=False)

yield_correlation.round(2)
# Out:
# Yield_Tonnes_Ha                  1.00
# Water_Efficiency_t_per_1000m3    0.92
# Production_Tonnes                0.89
# Profit_INR                       0.49
# Revenue_INR                      0.43
# Water_Used_m3                    0.39
# Nitrogen_kg_ha                   0.05
# Phosphorus_kg_ha                 0.05
# Total_Cost_INR                   0.03
# Farm_Area_Hectares               0.03
# Rainfall_mm                      0.03
# Disease_Pest_Risk_pct            0.01
# Humidity_pct                     0.01
# Soil_Moisture_pct                0.01
# Avg_Temperature_C                0.01
# Potassium_kg_ha                  0.00
# Fertilizer_kg_ha                 0.00
# Seed_Quality_Score              -0.01
# Pesticide_Litre_ha              -0.01
# Sunlight_Hours_Day              -0.02
# Soil_pH                         -0.02
# Market_Price_INR_Tonne          -0.38
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
important_cols = [
    "Rainfall_mm",
    "Avg_Temperature_C",
    "Humidity_pct",
    "Sunlight_Hours_Day",
    "Soil_pH",
    "Soil_Moisture_pct",
    "Nitrogen_kg_ha",
    "Phosphorus_kg_ha",
    "Potassium_kg_ha",
    "Fertilizer_kg_ha",
    "Pesticide_Litre_ha",
    "Seed_Quality_Score",
    "Water_Used_m3",
    "Disease_Pest_Risk_pct",
    "Yield_Tonnes_Ha"
]

important_corr = df_yield[important_cols].corr()

important_corr["Yield_Tonnes_Ha"].sort_values(ascending=False).round(2)
# Out:
# Yield_Tonnes_Ha          1.00
# Water_Used_m3            0.39
# Nitrogen_kg_ha           0.05
# Phosphorus_kg_ha         0.05
# Rainfall_mm              0.03
# Disease_Pest_Risk_pct    0.01
# Humidity_pct             0.01
# Soil_Moisture_pct        0.01
# Avg_Temperature_C        0.01
# Potassium_kg_ha          0.00
# Fertilizer_kg_ha         0.00
# Seed_Quality_Score      -0.01
# Pesticide_Litre_ha      -0.01
# Sunlight_Hours_Day      -0.02
# Soil_pH                 -0.02
# Name: Yield_Tonnes_Ha, dtype: float64

# %%
yield_corr = important_corr["Yield_Tonnes_Ha"].drop("Yield_Tonnes_Ha").sort_values()

plt.figure(figsize=(10,7))

yield_corr.plot(kind="barh")

plt.title("Correlation of Agricultural Factors with Crop Yield")
plt.xlabel("Correlation with Yield")
plt.ylabel("Factor")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df_yield,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha"
)

plt.title("Rainfall vs Crop Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Rainfall_mm",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Relationship Between Rainfall and Crop Yield")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Soil_Moisture_pct",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Soil Moisture vs Crop Yield")
plt.xlabel("Soil Moisture (%)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Avg_Temperature_C",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Temperature vs Crop Yield")
plt.xlabel("Average Temperature (°C)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Fertilizer_kg_ha",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Fertilizer Usage vs Crop Yield")
plt.xlabel("Fertilizer (kg/ha)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Seed_Quality_Score",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Seed Quality vs Crop Yield")
plt.xlabel("Seed Quality Score")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Disease_Pest_Risk_pct",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Disease and Pest Risk vs Crop Yield")
plt.xlabel("Disease/Pest Risk (%)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Water_Used_m3",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Water Usage vs Crop Yield")
plt.xlabel("Water Used (m³)")
plt.ylabel("Yield (Tonnes/Ha)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Yield_Tonnes_Ha",
    y="Revenue_INR",
    scatter_kws={"alpha": 0.4}
)

plt.title("Crop Yield vs Revenue")
plt.xlabel("Yield (Tonnes/Ha)")
plt.ylabel("Revenue (INR)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df_yield,
    x="Yield_Tonnes_Ha",
    y="Profit_INR",
    scatter_kws={"alpha": 0.4}
)

plt.title("Crop Yield vs Profit")
plt.xlabel("Yield (Tonnes/Ha)")
plt.ylabel("Profit (INR)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df,
    x="Production_Tonnes",
    y="Profit_INR",
    scatter_kws={"alpha": 0.4}
)

plt.title("Production vs Profit")
plt.xlabel("Production (Tonnes)")
plt.ylabel("Profit (INR)")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df,
    x="Total_Cost_INR",
    y="Profit_INR",
    scatter_kws={"alpha": 0.4}
)

plt.title("Farming Cost vs Profit")
plt.xlabel("Total Cost (INR)")
plt.ylabel("Profit (INR)")

plt.show()

# %%
kharif_yield = df_yield[df_yield["Season"] == "Kharif"]["Yield_Tonnes_Ha"]

rabi_yield = df_yield[df_yield["Season"] == "Rabi"]["Yield_Tonnes_Ha"]

zaid_yield = df_yield[df_yield["Season"] == "Zaid"]["Yield_Tonnes_Ha"]

# %%
from scipy.stats import f_oneway

f_stat, p_value = f_oneway(
    kharif_yield,
    rabi_yield,
    zaid_yield
)

print("F-statistic:", round(f_stat, 2))
print("p-value:", p_value)
# Out:
# F-statistic: 1.46
# p-value: 0.23283549440053075

# %%
# !pip install statsmodels
# Out:
# ...
#   Using cached statsmodels-0.15.0-cp314-cp314-win_amd64.whl.metadata (9.6 kB)
# ...
#   Using cached patsy-1.0.3-py2.py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached formulaic-1.2.2-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached interface_meta-2.0.1-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached narwhals-2.26.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached wrapt-2.4.1rc1-cp314-cp314-win_amd64.whl.metadata (7.6 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 2.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.3 MB 2.9 MB/s eta 0:00:04
#    ------ --------------------------------- 1.8/11.3 MB 2.7 MB/s eta 0:00:04
#    -------- ------------------------------- 2.4/11.3 MB 2.6 MB/s eta 0:00:04
# ...

# %%
from statsmodels.stats.multicomp import pairwise_tukeyhsd

tukey_result = pairwise_tukeyhsd(
    endog=df_yield["Yield_Tonnes_Ha"],
    groups=df_yield["Season"],
    alpha=0.05
)

print(tukey_result)
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
# Kharif   Rabi  -0.5635 0.4388 -1.6425 0.5155  False
# Kharif   Zaid   -0.978 0.2727 -2.4678 0.5118  False
#   Rabi   Zaid  -0.4146 0.7957 -1.9233 1.0942  False
# ---------------------------------------------------

# %%
kharif_profit = df[df["Season"] == "Kharif"]["Profit_INR"]

rabi_profit = df[df["Season"] == "Rabi"]["Profit_INR"]

zaid_profit = df[df["Season"] == "Zaid"]["Profit_INR"]

# %%
f_stat_profit, p_value_profit = f_oneway(
    kharif_profit,
    rabi_profit,
    zaid_profit
)

print("F-statistic:", round(f_stat_profit, 2))
print("p-value:", p_value_profit)
# Out:
# F-statistic: 34.29
# p-value: 1.7124156677397292e-15

# %%
tukey_profit = pairwise_tukeyhsd(
    endog=df["Profit_INR"],
    groups=df["Season"],
    alpha=0.05
)

print(tukey_profit)
# Out:
#        Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2   meandiff   p-adj    lower        upper     reject
# -----------------------------------------------------------------
# Kharif   Rabi  -91225.1774   0.0 -134704.3086  -47746.0461   True
# Kharif   Zaid -203719.4725   0.0 -263782.6023 -143656.3426   True
#   Rabi   Zaid -112494.2951   0.0 -173255.6664  -51732.9238   True
# -----------------------------------------------------------------

# %%
water_efficiency_season = df.groupby(
    "Season"
)["Water_Efficiency_t_per_1000m3"].mean().round(2)

water_efficiency_season
# Out:
# Season
# Kharif    5.89
# Rabi      5.19
# Zaid      4.41
# Name: Water_Efficiency_t_per_1000m3, dtype: float64

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=df,
    x="Season",
    y="Water_Efficiency_t_per_1000m3",
    estimator="mean"
)

plt.title("Water Efficiency Across Seasons")
plt.xlabel("Season")
plt.ylabel("Tonnes per 1000 m³")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.regplot(
    data=df,
    x="Water_Efficiency_t_per_1000m3",
    y="Profit_INR",
    scatter_kws={"alpha": 0.4}
)

plt.title("Water Efficiency vs Farm Profit")
plt.xlabel("Water Efficiency (Tonnes per 1000 m³)")
plt.ylabel("Profit (INR)")

plt.show()

# %%
df_yield.nlargest(
    10,
    "Yield_Tonnes_Ha"
)[
    [
        "Farm_ID",
        "State",
        "Crop",
        "Season",
        "Farm_Area_Hectares",
        "Yield_Tonnes_Ha",
        "Production_Tonnes",
        "Profit_INR"
    ]
]
# Out:
#       Farm_ID           State       Crop  Season  Farm_Area_Hectares  \
# 1715  SF11716         Gujarat  Sugarcane  Kharif                6.32
# 3423  SF13424  Andhra Pradesh  Sugarcane  Kharif               14.87
# 3525  SF13526  Andhra Pradesh  Sugarcane    Rabi                6.96
# 1464  SF11465         Gujarat  Sugarcane  Kharif                7.65
# 3523  SF13524       Karnataka  Sugarcane  Kharif                0.82
# 2782  SF12783         Gujarat  Sugarcane    Rabi                5.72
# 644   SF10645  Andhra Pradesh  Sugarcane  Kharif                7.48
# 2847  SF12848       Telangana  Sugarcane  Kharif                7.66
# 357   SF10358          Punjab  Sugarcane    Rabi               14.74
# 1178  SF11179       Karnataka  Sugarcane  Kharif                6.38
#
#       Yield_Tonnes_Ha  Production_Tonnes  Profit_INR
# 1715           101.44             641.10     1608291
# 3423            95.79            1424.40     3330582
# ...

# %%
df.nlargest(
    10,
    "Profit_INR"
)[
    [
        "Farm_ID",
        "State",
        "Crop",
        "Season",
        "Farm_Area_Hectares",
        "Production_Tonnes",
        "Revenue_INR",
        "Total_Cost_INR",
        "Profit_INR"
    ]
]
# Out:
#       Farm_ID           State       Crop  Season  Farm_Area_Hectares  \
# 2236  SF12237          Punjab     Chilli  Kharif               12.74
# 626   SF10627     Maharashtra     Chilli  Kharif               14.45
# 3425  SF13426  Madhya Pradesh  Sugarcane  Kharif               13.96
# 1690  SF11691       Karnataka     Chilli  Kharif               13.04
# 247   SF10248     Maharashtra     Chilli  Kharif               14.86
# 357   SF10358          Punjab  Sugarcane    Rabi               14.74
# 3423  SF13424  Andhra Pradesh  Sugarcane  Kharif               14.87
# 1930  SF11931      Tamil Nadu  Sugarcane  Kharif               14.16
# 3983  SF13984         Gujarat     Chilli  Kharif               13.68
# 263   SF10264     Maharashtra     Chilli    Rabi               13.95
#
#       Production_Tonnes  Revenue_INR  Total_Cost_INR  Profit_INR
# 2236              49.69      5057448          712027     4345421
# 626               42.19      5080900         1059050     4021850
# ...

# %%
df.nsmallest(
    10,
    "Profit_INR"
)[
    [
        "Farm_ID",
        "State",
        "Crop",
        "Season",
        "Farm_Area_Hectares",
        "Production_Tonnes",
        "Revenue_INR",
        "Total_Cost_INR",
        "Profit_INR"
    ]
]
# Out:
#       Farm_ID           State       Crop  Season  Farm_Area_Hectares  \
# 780   SF10781  Andhra Pradesh  Groundnut    Rabi               14.64
# 2210  SF12211  Andhra Pradesh      Wheat    Rabi               14.27
# 3625  SF13626          Punjab      Maize    Rabi               13.47
# 2182  SF12183  Andhra Pradesh       Rice  Kharif               14.72
# 104   SF10105         Gujarat      Wheat    Zaid               12.30
# 3394  SF13395         Gujarat      Wheat  Kharif               13.41
# 2730  SF12731  Madhya Pradesh       Rice    Rabi               11.99
# 1311  SF11312          Punjab       Rice    Zaid               13.55
# 585   SF10586       Telangana     Cotton    Zaid               13.96
# 3090  SF13091       Karnataka      Maize  Kharif               14.39
#
#       Production_Tonnes  Revenue_INR  Total_Cost_INR  Profit_INR
# 780                4.39       280139         1299362    -1019223
# 2210               4.28       102497         1097692     -995195
# ...

# %%
loss_by_season = df.groupby("Season").agg(
    Total_Farms=("Farm_ID", "count"),
    Loss_Making_Farms=("Profit_INR", lambda x: (x < 0).sum())
)

loss_by_season["Loss_Percentage"] = (
    loss_by_season["Loss_Making_Farms"] /
    loss_by_season["Total_Farms"] * 100
).round(2)

loss_by_season
# Out:
#         Total_Farms  Loss_Making_Farms  Loss_Percentage
# Season
# Kharif         1779                751            42.21
# Rabi           1627                832            51.14
# Zaid            594                383            64.48

# %%
plt.figure(figsize=(8,5))

sns.barplot(
    data=loss_by_season.reset_index(),
    x="Season",
    y="Loss_Percentage"
)

plt.title("Percentage of Loss-Making Farms by Season")
plt.xlabel("Season")
plt.ylabel("Loss-Making Farms (%)")

plt.show()

# %%
phase5_summary = pd.DataFrame({
    "Season": ["Kharif", "Rabi", "Zaid"],
    "Average_Yield": [
        df_yield[df_yield["Season"] == "Kharif"]["Yield_Tonnes_Ha"].mean(),
        df_yield[df_yield["Season"] == "Rabi"]["Yield_Tonnes_Ha"].mean(),
        df_yield[df_yield["Season"] == "Zaid"]["Yield_Tonnes_Ha"].mean()
    ],
    "Average_Profit": [
        df[df["Season"] == "Kharif"]["Profit_INR"].mean(),
        df[df["Season"] == "Rabi"]["Profit_INR"].mean(),
        df[df["Season"] == "Zaid"]["Profit_INR"].mean()
    ],
    "Average_Water_Used": [
        df[df["Season"] == "Kharif"]["Water_Used_m3"].mean(),
        df[df["Season"] == "Rabi"]["Water_Used_m3"].mean(),
        df[df["Season"] == "Zaid"]["Water_Used_m3"].mean()
    ],
    "Average_Water_Efficiency": [
        df[df["Season"] == "Kharif"]["Water_Efficiency_t_per_1000m3"].mean(),
        df[df["Season"] == "Rabi"]["Water_Efficiency_t_per_1000m3"].mean(),
        df[df["Season"] == "Zaid"]["Water_Efficiency_t_per_1000m3"].mean()
    ]
}).round(2)

phase5_summary
# Out:
#    Season  Average_Yield  Average_Profit  Average_Water_Used  \
# 0  Kharif           5.64       178914.65             6102.20
# 1    Rabi           5.08        87689.47             5846.99
# 2    Zaid           4.67       -24804.82             6419.89
#
#    Average_Water_Efficiency
# 0                      5.89
# 1                      5.19
# 2                      4.41

# %%
crop_season_yield = df_yield.pivot_table(
    index="Crop",
    columns="Season",
    values="Yield_Tonnes_Ha",
    aggfunc="mean"
).round(2)

crop_season_yield
# Out:
# Season     Kharif   Rabi   Zaid
# Crop
# Chilli       1.73   1.46   1.18
# Cotton       1.37   1.19   0.95
# Groundnut    1.48   1.22   1.04
# Maize        2.97   2.61   2.30
# Pulses       1.04   0.87   0.65
# Rice         2.71   2.33   1.90
# Sugarcane   53.46  43.94  38.42
# Wheat        2.26   2.06   1.75

# %%
crop_season_yield.plot(
    kind="bar",
    figsize=(12, 7)
)

plt.title("Average Crop Yield Across Seasons")
plt.xlabel("Crop")
plt.ylabel("Average Yield (Tonnes/Ha)")
plt.xticks(rotation=45)
plt.legend(title="Season")
plt.tight_layout()
plt.show()

# %%
crop_season_profit = df.pivot_table(
    index="Crop",
    columns="Season",
    values="Profit_INR",
    aggfunc="mean"
).round(2)

crop_season_profit
# Out:
# Season         Kharif       Rabi       Zaid
# Crop
# Chilli      954380.42  638572.50  448659.09
# Cotton      216999.55  107343.59  -53925.34
# Groundnut   108265.44   10416.54  -68872.50
# Maize       -39332.67  -89133.40 -194049.17
# Pulses       43338.90  -14309.14 -139227.81
# Rice        -64903.40  -98427.87 -227239.34
# Sugarcane  1000790.81  731612.86  583635.80
# Wheat      -105871.87 -119954.57 -193208.95

# %%
crop_season_profit.plot(
    kind="bar",
    figsize=(12, 7)
)

plt.title("Average Crop Profit Across Seasons")
plt.xlabel("Crop")
plt.ylabel("Average Profit (INR)")
plt.xticks(rotation=45)
plt.legend(title="Season")
plt.tight_layout()
plt.show()

# %%
best_crop_by_season = (
    df_yield.groupby(["Season", "Crop"])["Yield_Tonnes_Ha"]
    .mean()
    .reset_index()
)

best_crop_by_season.loc[
    best_crop_by_season.groupby("Season")["Yield_Tonnes_Ha"].idxmax()
]
# Out:
#     Season       Crop  Yield_Tonnes_Ha
# 6   Kharif  Sugarcane        53.459120
# 14    Rabi  Sugarcane        43.940394
# 22    Zaid  Sugarcane        38.423922

# %%
best_profit_crop = (
    df.groupby(["Season", "Crop"])["Profit_INR"]
    .mean()
    .reset_index()
)

best_profit_crop.loc[
    best_profit_crop.groupby("Season")["Profit_INR"].idxmax()
]
# Out:
#     Season       Crop    Profit_INR
# 6   Kharif  Sugarcane  1.000791e+06
# 14    Rabi  Sugarcane  7.316129e+05
# 22    Zaid  Sugarcane  5.836358e+05

# %%
state_season_yield = df_yield.pivot_table(
    index="State",
    columns="Season",
    values="Yield_Tonnes_Ha",
    aggfunc="mean"
).round(2)

state_season_yield
# Out:
# Season          Kharif  Rabi  Zaid
# State
# Andhra Pradesh    5.69  3.49  4.48
# Gujarat           6.34  5.52  4.10
# Karnataka         6.52  4.61  6.62
# Madhya Pradesh    6.00  3.80  5.54
# Maharashtra       5.45  5.50  2.29
# Punjab            4.10  8.61  5.91
# Tamil Nadu        5.52  4.56  4.10
# Telangana         5.57  4.83  4.28

# %%
state_season_profit = df.pivot_table(
    index="State",
    columns="Season",
    values="Profit_INR",
    aggfunc="mean"
).round(2)

state_season_profit
# Out:
# Season             Kharif       Rabi       Zaid
# State
# Andhra Pradesh  169315.52   26315.71  -84084.87
# Gujarat         217051.33   82846.20 -106929.61
# Karnataka       201226.21   70952.61   23310.91
# Madhya Pradesh  134242.40   61576.26     209.70
# Maharashtra     168801.05  159581.50  -40597.60
# Punjab          133779.10  169294.52   62109.69
# Tamil Nadu      211303.96   70456.86  -15175.20
# Telangana       199668.38   62824.60  -34620.78

# %%
state_performance = df_yield.groupby("State").agg(
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Average_Profit=("Profit_INR", "mean"),
    Average_Water_Used=("Water_Used_m3", "mean"),
    Average_Disease_Risk=("Disease_Pest_Risk_pct", "mean")
).round(2)

state_performance.sort_values(
    "Average_Yield",
    ascending=False
)
# Out:
#                 Average_Yield  Average_Profit  Average_Water_Used  \
# State
# Punjab                   6.12       136025.64             6565.92
# Karnataka                5.73       118495.57             6418.22
# Gujarat                  5.70       120050.96             6120.73
# Telangana                5.08       108282.06             5774.68
# Maharashtra              5.03       136874.14             5977.12
# Madhya Pradesh           5.03        89479.77             5612.88
# Tamil Nadu               4.90       119117.82             5800.76
# Andhra Pradesh           4.65        69497.23             6062.46
#
#                 Average_Disease_Risk
# State
# Punjab                         46.00
# Karnataka                      46.09
# Gujarat                        45.99
# Telangana                      46.38
# Maharashtra                    46.44
# Madhya Pradesh                 47.12
# Tamil Nadu                     46.40
# Andhra Pradesh                 46.79

# %%
state_seasonal_stability = df_yield.groupby(
    ["State", "Season"]
)["Yield_Tonnes_Ha"].mean().reset_index()

state_stability = state_seasonal_stability.groupby(
    "State"
)["Yield_Tonnes_Ha"].agg(["mean", "std"]).round(2)

state_stability
# Out:
#                 mean   std
# State
# Andhra Pradesh  4.55  1.10
# Gujarat         5.32  1.13
# Karnataka       5.92  1.13
# Madhya Pradesh  5.11  1.16
# Maharashtra     4.41  1.84
# Punjab          6.21  2.27
# Tamil Nadu      4.72  0.73
# Telangana       4.89  0.65

# %%
crop_seasonal_stability = df_yield.groupby(
    ["Crop", "Season"]
)["Yield_Tonnes_Ha"].mean().reset_index()

crop_stability = crop_seasonal_stability.groupby(
    "Crop"
)["Yield_Tonnes_Ha"].agg(["mean", "std"]).round(2)

crop_stability.sort_values("std")
# Out:
#             mean   std
# Crop
# Pulses      0.85  0.19
# Cotton      1.17  0.21
# Groundnut   1.25  0.22
# Wheat       2.02  0.26
# Chilli      1.46  0.28
# Maize       2.63  0.33
# Rice        2.31  0.40
# Sugarcane  45.27  7.61

# %%
seasonal_change = crop_season_yield.copy()

seasonal_change["Kharif_to_Zaid_Change_pct"] = (
    (seasonal_change["Zaid"] - seasonal_change["Kharif"])
    / seasonal_change["Kharif"]
) * 100

seasonal_change[
    ["Kharif", "Zaid", "Kharif_to_Zaid_Change_pct"]
].round(2).sort_values(
    "Kharif_to_Zaid_Change_pct"
)
# Out:
# Season     Kharif   Zaid  Kharif_to_Zaid_Change_pct
# Crop
# Pulses       1.04   0.65                     -37.50
# Chilli       1.73   1.18                     -31.79
# Cotton       1.37   0.95                     -30.66
# Rice         2.71   1.90                     -29.89
# Groundnut    1.48   1.04                     -29.73
# Sugarcane   53.46  38.42                     -28.13
# Wheat        2.26   1.75                     -22.57
# Maize        2.97   2.30                     -22.56

# %%
state_change = state_season_yield.copy()

state_change["Kharif_to_Zaid_Change_pct"] = (
    (state_change["Zaid"] - state_change["Kharif"])
    / state_change["Kharif"]
) * 100

state_change[
    ["Kharif", "Zaid", "Kharif_to_Zaid_Change_pct"]
].round(2).sort_values(
    "Kharif_to_Zaid_Change_pct"
)
# Out:
# Season          Kharif  Zaid  Kharif_to_Zaid_Change_pct
# State
# Maharashtra       5.45  2.29                     -57.98
# Gujarat           6.34  4.10                     -35.33
# Tamil Nadu        5.52  4.10                     -25.72
# Telangana         5.57  4.28                     -23.16
# Andhra Pradesh    5.69  4.48                     -21.27
# Madhya Pradesh    6.00  5.54                      -7.67
# Karnataka         6.52  6.62                       1.53
# Punjab            4.10  5.91                      44.15

# %%
df_yield["Fertilizer_Efficiency"] = (
    df_yield["Yield_Tonnes_Ha"] /
    df_yield["Fertilizer_kg_ha"]
) * 100

fertilizer_efficiency = df_yield.groupby(
    "Season"
)["Fertilizer_Efficiency"].mean().round(2)

fertilizer_efficiency
# Out:
# Season
# Kharif    3.49
# Rabi      3.11
# Zaid      2.76
# Name: Fertilizer_Efficiency, dtype: float64

# %%
water_efficiency = df.groupby("Season").agg(
    Average_Water_Used=("Water_Used_m3", "mean"),
    Average_Water_Efficiency=(
        "Water_Efficiency_t_per_1000m3",
        "mean"
    )
).round(2)

water_efficiency
# Out:
#         Average_Water_Used  Average_Water_Efficiency
# Season
# Kharif             6102.20                      5.89
# Rabi               5846.99                      5.19
# Zaid               6419.89                      4.41

# %%
water_efficiency["Average_Water_Efficiency"].plot(
    kind="bar",
    figsize=(8, 5)
)

plt.title("Water Efficiency Across Seasons")
plt.xlabel("Season")
plt.ylabel("Water Efficiency (Tonnes per 1000 m³)")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
yield_median = df_yield["Yield_Tonnes_Ha"].median()

yield_median
# Out:
# np.float64(1.74)

# %%
high_yield_low_profit = df_yield[
    (df_yield["Yield_Tonnes_Ha"] > yield_median) &
    (df_yield["Profit_INR"] < 0)
]

high_yield_low_profit.shape
# Out:
# (759, 29)

# %%
high_yield_low_profit[
    [
        "Farm_ID",
        "State",
        "Crop",
        "Season",
        "Yield_Tonnes_Ha",
        "Production_Tonnes",
        "Market_Price_INR_Tonne",
        "Total_Cost_INR",
        "Revenue_INR",
        "Profit_INR"
    ]
].sort_values(
    "Profit_INR"
).head(10)
# Out:
#       Farm_ID           State       Crop  Season  Yield_Tonnes_Ha  \
# 156   SF10157          Punjab  Sugarcane  Kharif             4.19
# 1296  SF11297       Karnataka  Sugarcane  Kharif             3.27
# 3457  SF13458      Tamil Nadu  Sugarcane    Rabi             2.63
# 1556  SF11557  Madhya Pradesh       Rice    Rabi             1.92
# 907   SF10908      Tamil Nadu      Maize    Zaid             2.35
# 2979  SF12980         Gujarat  Sugarcane  Kharif             7.70
# 2193  SF12194          Punjab  Sugarcane  Kharif             4.86
# 1352  SF11353  Andhra Pradesh       Rice    Zaid             2.55
# 338   SF10339          Punjab      Wheat  Kharif             1.95
# 2051  SF12052     Maharashtra      Wheat  Kharif             1.86
#
#       Production_Tonnes  Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  \
# 156               60.42                    3027          907734       182891
# 1296              33.52                    3136          785319       105119
# ...

# %%
low_yield_high_profit = df_yield[
    (df_yield["Yield_Tonnes_Ha"] < yield_median) &
    (df_yield["Profit_INR"] > 0)
]

low_yield_high_profit.shape
# Out:
# (791, 29)

# %%
low_yield_high_profit[
    [
        "Farm_ID",
        "State",
        "Crop",
        "Season",
        "Yield_Tonnes_Ha",
        "Market_Price_INR_Tonne",
        "Total_Cost_INR",
        "Revenue_INR",
        "Profit_INR"
    ]
].sort_values(
    "Profit_INR",
    ascending=False
).head(10)
# Out:
#       Farm_ID           State    Crop  Season  Yield_Tonnes_Ha  \
# 1310  SF11311          Punjab  Chilli    Rabi             1.65
# 1091  SF11092          Punjab  Chilli    Rabi             1.70
# 1443  SF11444      Tamil Nadu  Chilli  Kharif             1.48
# 1274  SF11275          Punjab  Chilli  Kharif             1.66
# 209   SF10210     Maharashtra  Chilli    Rabi             1.42
# 3145  SF13146  Andhra Pradesh  Chilli  Kharif             1.55
# 1110  SF11111  Madhya Pradesh  Chilli    Rabi             1.69
# 1593  SF11594  Andhra Pradesh  Pulses    Rabi             1.60
# 3400  SF13401         Gujarat  Chilli    Zaid             1.62
# 2691  SF12692  Madhya Pradesh  Chilli    Rabi             1.56
#
#       Market_Price_INR_Tonne  Total_Cost_INR  Revenue_INR  Profit_INR
# 1310                  112879          586190      2429156     1842966
# 1091                  120569          856215      2523509     1667294
# ...

# %%
irrigation_performance = df_yield.groupby("Irrigation_Method").agg(
    Average_Yield=("Yield_Tonnes_Ha", "mean"),
    Average_Profit=("Profit_INR", "mean"),
    Average_Water_Used=("Water_Used_m3", "mean"),
    Average_Water_Efficiency=(
        "Water_Efficiency_t_per_1000m3",
        "mean"
    ),
    Number_of_Farms=("Farm_ID", "count")
).round(2)

irrigation_performance.sort_values(
    "Average_Yield",
    ascending=False
)
# Out:
#                    Average_Yield  Average_Profit  Average_Water_Used  \
# Irrigation_Method
# Drip                        6.62       219002.41             5901.44
# Sprinkler                   5.19        93844.83             6210.70
# Flood                       4.90        72918.99             8028.81
# Rainfed                     4.61        79509.51             3551.55
#
#                    Average_Water_Efficiency  Number_of_Farms
# Irrigation_Method
# Drip                                   6.23              907
# Sprinkler                              4.69              728
# Flood                                  3.46             1296
# Rainfed                                7.57             1037

# %%
irrigation_season_yield = df_yield.pivot_table(
    index="Irrigation_Method",
    columns="Season",
    values="Yield_Tonnes_Ha",
    aggfunc="mean"
).round(2)

irrigation_season_yield
# Out:
# Season             Kharif  Rabi  Zaid
# Irrigation_Method
# Drip                 7.26  6.21  5.85
# Flood                5.00  5.10  4.03
# Rainfed              5.72  3.94  3.06
# Sprinkler            4.67  5.36  6.17

# %%
irrigation_season_profit = df.pivot_table(
    index="Irrigation_Method",
    columns="Season",
    values="Profit_INR",
    aggfunc="mean"
).round(2)

irrigation_season_profit
# Out:
# Season                Kharif       Rabi      Zaid
# Irrigation_Method
# Drip               317222.07  187843.22  21291.84
# Flood              133373.83   58824.80 -69786.78
# Rainfed            158974.13   45232.48 -79467.26
# Sprinkler          116880.49   76502.07  57909.40

# %%
fertilizer_season = df.groupby("Season").agg(
    Average_Fertilizer=("Fertilizer_kg_ha", "mean"),
    Average_Yield=("Yield_Tonnes_Ha", "mean")
).round(2)

fertilizer_season
# Out:
#         Average_Fertilizer  Average_Yield
# Season
# Kharif              187.08           5.64
# Rabi                185.41           5.08
# Zaid                184.64           4.67

# %%
plt.figure(figsize=(9, 6))

sns.regplot(
    data=df_yield,
    x="Fertilizer_kg_ha",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Relationship Between Fertilizer Usage and Crop Yield")
plt.xlabel("Fertilizer (kg/ha)")
plt.ylabel("Yield (Tonnes/ha)")
plt.tight_layout()
plt.show()

# %%
seed_quality_analysis = df_yield.groupby(
    pd.cut(
        df_yield["Seed_Quality_Score"],
        bins=[0.64, 0.75, 0.85, 0.95, 1.00],
        labels=["Low", "Medium", "High", "Very High"]
    )
)["Yield_Tonnes_Ha"].agg(
    Average_Yield="mean",
    Number_of_Farms="count"
).round(2)

seed_quality_analysis
# Out:
#                     Average_Yield  Number_of_Farms
# Seed_Quality_Score
# Low                          5.06             1197
# Medium                       5.84             1105
# High                         5.08             1139
# Very High                    4.98              527

# %%
disease_risk_analysis = df_yield.groupby(
    pd.cut(
        df_yield["Disease_Pest_Risk_pct"],
        bins=[0, 25, 50, 75, 100],
        labels=["Low Risk", "Moderate Risk", "High Risk", "Very High Risk"]
    )
)["Yield_Tonnes_Ha"].agg(
    Average_Yield="mean",
    Number_of_Farms="count"
).round(2)

disease_risk_analysis
# Out:
#                        Average_Yield  Number_of_Farms
# Disease_Pest_Risk_pct
# Low Risk                        4.94              152
# Moderate Risk                   5.16             2289
# High Risk                       5.49             1490
# Very High Risk                  5.07               37

# %%
plt.figure(figsize=(9, 6))

sns.regplot(
    data=df_yield,
    x="Disease_Pest_Risk_pct",
    y="Yield_Tonnes_Ha",
    scatter_kws={"alpha": 0.4}
)

plt.title("Relationship Between Disease/Pest Risk and Crop Yield")
plt.xlabel("Disease/Pest Risk (%)")
plt.ylabel("Yield (Tonnes/ha)")
plt.tight_layout()
plt.show()

# %%
soil_ph_analysis = df_yield.groupby(
    pd.cut(
        df_yield["Soil_pH"],
        bins=[5.0, 6.0, 7.0, 8.0, 9.0],
        labels=["Acidic", "Slightly Acidic/Neutral", "Neutral/Alkaline", "Alkaline"]
    )
)["Yield_Tonnes_Ha"].agg(
    Average_Yield="mean",
    Number_of_Farms="count"
).round(2)

soil_ph_analysis
# Out:
#                          Average_Yield  Number_of_Farms
# Soil_pH
# Acidic                            2.37              550
# Slightly Acidic/Neutral           6.83             2168
# Neutral/Alkaline                  4.09             1163
# Alkaline                          0.57               87

# %%
from sklearn.preprocessing import StandardScaler

score_data = df_yield[
    [
        "Yield_Tonnes_Ha",
        "Profit_INR",
        "Water_Efficiency_t_per_1000m3"
    ]
].copy()

scaler = StandardScaler()

score_data[
    [
        "Yield_Score",
        "Profit_Score",
        "Water_Efficiency_Score"
    ]
] = scaler.fit_transform(score_data)

score_data["Overall_Performance_Score"] = (
    score_data["Yield_Score"] +
    score_data["Profit_Score"] +
    score_data["Water_Efficiency_Score"]
) / 3

score_data.head()
# Out:
#    Yield_Tonnes_Ha  Profit_INR  Water_Efficiency_t_per_1000m3  Yield_Score  \
# 0             2.46      -11852                          5.485    -0.210378
# 1             0.30     -451950                          0.396    -0.372058
# 2             0.52     -124744                          1.984    -0.355591
# 3             1.84      -95704                          2.160    -0.256787
# 4             2.21     -144352                          2.829    -0.229091
#
#    Profit_Score  Water_Efficiency_Score  Overall_Performance_Score
# 0     -0.226736                0.010273                  -0.142281
# 1     -1.033258               -0.565105                  -0.656807
# 2     -0.433622               -0.385561                  -0.391591
# 3     -0.380403               -0.365662                  -0.334284
# 4     -0.469555               -0.290023                  -0.329556

# %%
df_yield["Overall_Performance_Score"] = (
    score_data["Overall_Performance_Score"]
)

df_yield.nlargest(
    10,
    "Overall_Performance_Score"
)[
    [
        "Farm_ID",
        "State",
        "Crop",
        "Season",
        "Yield_Tonnes_Ha",
        "Profit_INR",
        "Water_Efficiency_t_per_1000m3",
        "Overall_Performance_Score"
    ]
]
# Out:
#       Farm_ID           State       Crop  Season  Yield_Tonnes_Ha  Profit_INR  \
# 3423  SF13424  Andhra Pradesh  Sugarcane  Kharif            95.79     3330582
# 1347  SF11348  Andhra Pradesh  Sugarcane  Kharif            76.14     2244614
# 3425  SF13426  Madhya Pradesh  Sugarcane  Kharif            82.68     3740099
# 357   SF10358          Punjab  Sugarcane    Rabi            84.75     3378879
# 1930  SF11931      Tamil Nadu  Sugarcane  Kharif            79.25     3232970
# 3482  SF13483      Tamil Nadu  Sugarcane  Kharif            77.32     1925043
# 222   SF10223     Maharashtra  Sugarcane    Rabi            72.54     2578433
# 1464  SF11465         Gujarat  Sugarcane  Kharif            91.98     2216708
# 3407  SF13408       Karnataka  Sugarcane  Kharif            63.71     2101276
# 644   SF10645  Andhra Pradesh  Sugarcane  Kharif            89.34     1984818
#
#       Water_Efficiency_t_per_1000m3  Overall_Performance_Score
# ...

# %%
final_season_summary = df.groupby("Season").agg(
    Farms=("Farm_ID", "count"),
    Avg_Yield=("Yield_Tonnes_Ha", "mean"),
    Avg_Profit=("Profit_INR", "mean"),
    Avg_Rainfall=("Rainfall_mm", "mean"),
    Avg_Temperature=("Avg_Temperature_C", "mean"),
    Avg_Water_Used=("Water_Used_m3", "mean"),
    Avg_Water_Efficiency=(
        "Water_Efficiency_t_per_1000m3",
        "mean"
    ),
    Avg_Disease_Risk=("Disease_Pest_Risk_pct", "mean")
).round(2)

final_season_summary
# Out:
#         Farms  Avg_Yield  Avg_Profit  Avg_Rainfall  Avg_Temperature  \
# Season
# Kharif   1779       5.64   178914.65        852.11            28.45
# Rabi     1627       5.08    87689.47        435.94            23.49
# Zaid      594       4.67   -24804.82        299.12            31.04
#
#         Avg_Water_Used  Avg_Water_Efficiency  Avg_Disease_Risk
# Season
# Kharif         6102.20                  5.89             54.47
# Rabi           5846.99                  5.19             40.48
# Zaid           6419.89                  4.41             38.22

# %%
final_crop_summary = df.groupby("Crop").agg(
    Avg_Yield=("Yield_Tonnes_Ha", "mean"),
    Avg_Profit=("Profit_INR", "mean"),
    Avg_Water_Used=("Water_Used_m3", "mean"),
    Avg_Disease_Risk=("Disease_Pest_Risk_pct", "mean"),
    Number_of_Farms=("Farm_ID", "count")
).round(2)

final_crop_summary.sort_values(
    "Avg_Profit",
    ascending=False
)
# Out:
#            Avg_Yield  Avg_Profit  Avg_Water_Used  Avg_Disease_Risk  \
# Crop
# Sugarcane      46.94   817187.99        13897.70             45.40
# Chilli          1.54   750878.34         4577.47             46.06
# Cotton          1.23   124546.92         5410.86             45.97
# Groundnut       1.32    44858.12         3459.54             46.29
# Pulses          0.92    -4238.05         2833.67             46.57
# Maize           2.72   -83978.33         4377.78             45.54
# Rice            2.44  -102213.50        10920.22             46.50
# Wheat           2.11  -123398.34         4054.40             47.85
#
#            Number_of_Farms
# Crop
# Sugarcane              305
# Chilli                 412
# Cotton                 508
# Groundnut              424
# Pulses                 496
# Maize                  551
# Rice                   690
# Wheat                  614
